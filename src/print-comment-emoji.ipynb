# %%
print("💬 This is user message.")
print("✔ Response is correct.")
print("🤖 This is AI Agent Message.")
print("✖ This is AI Agent Message.")
print("❯❯❯❯ Final Response.")
print("💭 This is user message.")
# Out:
# 💬 This is user message.
# ✔ Response is correct.
# 🤖 This is AI Agent Message.
# ✖ This is AI Agent Message.
# ❯❯❯❯ Final Response.
# 💭 This is user message.
