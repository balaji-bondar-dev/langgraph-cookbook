# %%
# print("LangChain-Salesforce Integraion.")
# export SALESFORCE_USERNAME="your-username@company.com"
# export SALESFORCE_PASSWORD="your-password"
# export SALESFORCE_SECURITY_TOKEN="your-security-token"
# export SALESFORCE_DOMAIN="login"  # Use "test" for sandbox environments

# %%
import os
from dotenv import load_dotenv
from langchain_salesforce import SalesforceTool

load_dotenv()

username = os.getenv("SALESFORCE_USERNAME")
password = os.getenv("SALESFORCE_PASSWORD", "your-password")
security_token = os.getenv("SALESFORCE_SECURITY_TOKEN", "your-security-token")
domain = os.getenv("SALESFORCE_DOMAIN", "login")

tool = SalesforceTool(
    username=username, password=password, security_token=security_token, domain=domain
)
print("final response ")

# %%
def execute_salesforce_operation(
    operation, object_name=None, query=None, record_data=None, record_id=None
):
    """Executes a given Salesforce operation."""
    request = {"operation": operation}
    if object_name:
        request["object_name"] = object_name
    if query:
        request["query"] = query
    if record_data:
        request["record_data"] = record_data
    if record_id:
        request["record_id"] = record_id
    result = tool.invoke(request)
    return result

# %%
query_result = execute_salesforce_operation(
    operation="query", query="SELECT Id, Name, Email FROM Contact LIMIT 5"
)
print(query_result)

# %%
describe_result = execute_salesforce_operation(
    operation="describe", object_name="Account"
)
print(describe_result)

# %%
list_objects_result = execute_salesforce_operation(operation="list_objects")
print(list_objects_result)
# Out:
# [OrderedDict({'activateable': False, 'associateEntityType': None, 'associateParentEntity': None, 'createable': False, 'custom': False, 'customSetting': False, 'deepCloneable': False, 'deletable': False, 'deprecatedAndHidden': False, 'feedEnabled': False, 'hasSubtypes': False, 'isInterface': False, 'isSubtype': False, 'keyPrefix': 'qGu', 'label': 'ADL_Loan_Data', 'labelPlural': 'ADL_Loan_Data', 'layoutable': False, 'mergeable': False, 'mruEnabled': False, 'name': 'ADL_Loan_Data__dlm', 'queryable': True, 'replicateable': False, 'retrieveable': False, 'searchable': False, 'triggerable': False, 'undeletable': False, 'updateable': False, 'urls': OrderedDict({'rowTemplate': '/services/data/v59.0/sobjects/ADL_Loan_Data__dlm/{ID}', 'describe': '/services/data/v59.0/sobjects/ADL_Loan_Data__dlm/describe', 'sobject': '/services/data/v59.0/sobjects/ADL_Loan_Data__dlm'})}), OrderedDict({'activateable': False, 'associateEntityType': None, 'associateParentEntity': None, 'createable': False, 'custom': False, 'customSetting': False, 'deepCloneable': False, 'deletable': False, 'deprecatedAndHidden': False, 'feedEnabled': False, 'hasSubtypes': False, 'isInterface': False, 'isSubtype': False, 'keyPrefix': '0Pp', 'label': 'AI Application', 'labelPlural': 'AI Applications', 'layoutable': False, 'mergeable': False, 'mruEnabled': False, 'name': 'AIApplication', 'queryable': True, 'replicateable': False, 'retrieveable': True, 'searchable': False, 'triggerable': False, 'undeletable': False, 'updateable': False, 'urls': OrderedDict({'rowTemplate': '/services/data/v59.0/sobjects/AIApplication/{ID}', 'describe': '/services/data/v59.0/sobjects/AIApplication/describe', 'sobject': '/services/data/v59.0/sobjects/AIApplication'})}), OrderedDict({'activateable': False, 'associateEntityType': None, 'associateParentEntity': None, 'createable': False, 'custom': False, 'customSetting': False, 'deepCloneable': False, 'deletable': False, 'deprecatedAndHidden': False, 'feedEnabled': False, 'hasSubtypes': False, 'isInterface': False, 'isSubtype': False, 'keyPrefix': '6S9', 'label': 'AI Application Configuration', 'labelPlural': 'AI Application Configurations', 'layoutable': False, 'mergeable': False, 'mruEnabled': False, 'name': 'AIApplicationConfig', 'queryable': True, 'replicateable': False, 'retrieveable': True, 'searchable': False, 'triggerable': False, 'undeletable': False, 'updateable': False, 'urls': OrderedDict({'rowTemplate': '/services/data/v59.0/sobjects/AIApplicationConfig/{ID}', 'describe': '/services/data/v59.0/sobjects/AIApplicationConfig/describe', 'sobject': '/services/data/v59.0/sobjects/AIApplicationConfig'})}), OrderedDict({'activateable': False, 'associateEntityType': None, 'associateParentEntity': None, 'createable': False, 'custom': False, 'customSetting': False, 'deepCloneable': False, 'deletable': False, 'deprecatedAndHidden': False, 'feedEnabled': False, 'hasSubtypes': False, 'isInterface': False, 'isSubtype': False, 'keyPrefix': '9qd', 'label': 'AIInsightAction', 'labelPlural': 'AIInsightActions', 'layoutable': False, 'mergeable': False, 'mruEnabled': False, 'name': 'AIInsightAction', 'queryable': True, 'replicateable': True, 'retrieveable': True, 'searchable': False, 'triggerable': False, 'undeletable': False, 'updateable': False, 'urls': OrderedDict({'rowTemplate': '/services/data/v59.0/sobjects/AIInsightAction/{ID}', 'describe': '/services/data/v59.0/sobjects/AIInsightAction/describe', 'sobject': '/services/data/v59.0/sobjects/AIInsightAction'})}), OrderedDict({'activateable': False, 'associateEntityType': None, 'associateParentEntity': None, 'createable': False, 'custom': False, 'customSetting': False, 'deepCloneable': False, 'deletable': False, 'deprecatedAndHidden': False, 'feedEnabled': False, 'hasSubtypes': False, 'isInterface': False, 'isSubtype': False, 'keyPrefix': '9bq', 'label': 'AI Insight Feedback', 'labelPlural': 'AI Insight Feedbacks', 'layoutable': False, 'mergeable': False, 'mruEnabled': False, 'name': 'AIInsightFeedback',  ...

# %%
create_result = execute_salesforce_operation(
    operation="create",
    object_name="Contact",
    record_data={"LastName": "Doe", "Email": "doe@example.com"},
)
print(create_result)
# Out:
# OrderedDict({'id': '003dM000021pjeFQAQ', 'success': True, 'errors': []})

# %%
update_result = execute_salesforce_operation(
    operation="update",
    object_name="Contact",
    record_id="003dM000021pjeFQAQ",
    record_data={"Email": "updated@example.com"},
)
print(update_result)
# Out:
# 204

# %%
delete_result = execute_salesforce_operation(
    operation="delete", object_name="Contact", record_id="003XXXXXXXXXXXXXXX"
)
prinnt(delete_result)
# Out:
# ---------------------------------------------------------------------------
# SalesforceResourceNotFound                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 delete_result = execute_salesforce_operation(
#       2     operation="delete", object_name="Contact", record_id="003XXXXXXXXXXXXXXX"
#       3 )
#       4 prinnt(delete_result)
#
# Cell In[34], line 14, in execute_salesforce_operation(operation, object_name, query, record_data, record_id)
#      10     if record_data:
#      11         request["record_data"] = record_data
#      12     if record_id:
#      13         request["record_id"] = record_id
# ---> 14     result = tool.invoke(request)
#      15     return result
#
# File c:\Users\balaj\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_salesforce\tools.py:304, in SalesforceTool.invoke(self, input, config, **kwargs)
#     302 """Run the tool."""
#     303 input_dict = self._parse_salesforce_input(input)
# --> 304 return self._run(**input_dict)
#
# File c:\Users\balaj\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_salesforce\tools.py:270, in SalesforceTool._run(self, operation, object_name, query, record_data, record_id, field_name, run_manager)
#     268 self._validate_operation_params(operation, **params)
#     269 operation_func = operations[operation]
# --> 270 return operation_func(**params)
#
# File c:\Users\balaj\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_salesforce\tools.py:150, in SalesforceTool._execute_delete(self, object_name, record_id, **kwargs)
#     146 def _execute_delete(
#     147     self, object_name: str, record_id: str, **kwargs: Any
#     148 ) -> Dict[str, Any]:
#     149     """Execute a delete operation."""
# --> 150     return getattr(self._sf, object_name).delete(record_id)
#
# File c:\Users\balaj\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\simple_salesforce\api.py:1169, in SFType.delete(self, record_id, raw_response, headers)
#    1152 def delete(
#    1153         self,
#    1154         record_id: str,
#    1155         raw_response: bool = False,
#    1156         headers: Optional[Headers] = None
#    1157         ) -> Union[int, requests.Response]:
#    1158     """Deletes an SObject using a DELETE to
#    1159     `.../{object_name}/{record_id}`.
#    1160     If `raw_response` is false (the default), returns the status code
#    (...)   1167     * headers -- a dict with additional request headers.
#    1168     """
# -> 1169     result = self._call_salesforce(
#    1170         method='DELETE',
#    1171         url=urljoin(self.base_url,
#    1172                     record_id
#    1173                     ),
#    1174         headers=headers
#    1175         )
#    1176     return self._raw_response(result,
#    1177                               raw_response
#    1178                               )
#
# File c:\Users\balaj\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\simple_salesforce\api.py:1279, in SFType._call_salesforce(self, method, url, retries, max_retries, **kwargs)
#    1273         return self._call_salesforce(method,
#    1274                                      url,
#    1275                                      **kwargs
#    1276                                      )
#    1278 if result.status_code >= 300:
# -> 1279     exception_handler(result,
#    1280                       self.name
#    1281                       )
#    1283 sforce_limit_info = result.headers.get('Sforce-Limit-Info')
#    1284 if sforce_limit_info:
#
# File c:\Users\balaj\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\simple_salesforce\util.py:89, in exception_handler(result, name)
#      80 exc_map = {
#      81     300: SalesforceMoreThanOneRecord,
#      82     400: SalesforceMalformedRequest,
#    (...)     85     404: SalesforceResourceNotFound,
#      86 }
#      87 exc_cls = exc_map.get(result.status_code, SalesforceGeneralError)
# ---> 89 raise exc_cls(result.url, result.status_code, name, response_content)
#
# SalesforceResourceNotFound: Resource Contact Not Found. Response content: [{'errorCode': 'NOT_FOUND', 'message': 'Provided external ID field does not exist or is not accessible: 003XXXXXXXXXXXXXXX'}]
